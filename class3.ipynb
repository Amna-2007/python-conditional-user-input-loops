# %% [markdown]
# ### conditional statetment

# %% [markdown]
# - if internet_available --> class will be conducted
# - else --> there will be no class

# %% [markdown]
# ### Syntax

# %% [markdown]
# if <conditiobn>:
#     <boby of it>
# else:
#     <boby of else>

# %%
True and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
internetAvailable = True
independenceDay = "no"
if independenceDay == "yes" and internetAvailable:
    print("independence activity will be held")
elif internetAvailable:
    print("print class will be conducted") 
else:
    print("class/activity will not be conducted")
# Out:
# print class will be conducted

# %% [markdown]
# A school has following rules for grading system
#
#
# - below 25-F
# - 25 to 45-E
# - 45 to 50-D
# - 50 to 60-C
# - 60 to 80-B
# - Above 80-A
#
# Ask user to enter marks and print corresponding grade

# %%
marks = 78

# %%
if marks > 80 and marks <=100:
    print("your grade is A")
elif marks > 60 and marks <=80:
    print("your grade is B") 
elif marks > 50 and marks <=60:
    print("your grade is C")
elif marks > 45 and marks <=50:
    print("your grade is D") 
elif marks > 25 and marks <=45:
    print("your grade is E") 
elif marks > 0 and marks <= 25:
    print("your grade is F")
else:
    print("invalid input")
# Out:
# your grade is B

# %% [markdown]
# write a program to check weather a number is entered by a user is even or odd

# %%
number = 453
if number % 2 ==0:
    print("even")
else:
    print("odd")
# Out:
# odd

# %% [markdown]
# ### user input

# %%
name = input("Enter your name")
type(name)
# Out:
# str

# %%
number = int(input("Enter your number"))
if number % 2 ==0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
var = int(input("Enter anything:"))
print(type(var))
print(var)
# Out:
# <class 'int'>
# 43463

# %%
var = input("Enter Anything: ")
print(var)
print(type(var))
# Out:
# Amna kaber
# <class 'str'>

# %% [markdown]
# ### Concatenation

# %%
fname = "Amna"
lname = "kabeer"

# %% [markdown]
# Method 1 using + operator

# %%
fname + lname
# Out:
# 'Amnakabeer'

# %%
fname + " " + lname
# Out:
# 'Amna kabeer'

# %% [markdown]
# Metohd using f string

# %%
fullname = f"{fname} {lname}"

# %%
fullname
# Out:
# 'Amna kabeer'

# %%
marks = 90

# %%
f"your marks are: {marks}"
# Out:
# 'your marks are: 90'

# %% [markdown]
# ### Note
#
# - for concatenation using `+` operator you have to `TYPE` cast.
# - for concatenation using `f` you don't need to `TYPE` cast.
